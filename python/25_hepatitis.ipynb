# %%
import pandas as pd

# %%
df=pd.read_csv("DSBDALExam DataSets/Hepatitis/hepatitis_csv.csv")
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
male_subset = df[df['sex'] == 'male']
female_subset = df[df['sex'] == 'female']

# %%
merged_df = pd.merge(male_subset, female_subset,on='age')
merged_df
# Out:
#     age sex_x steroid_x  antivirals_x fatigue_x malaise_x anorexia_x  \
# 0    30  male     False         False     False     False      False
# 1    30  male     False         False     False     False      False
# 2    30  male     False         False     False     False      False
# 3    30  male     False         False     False     False      False
# 4    30  male     False         False     False     False      False
# 5    30  male     False         False     False     False      False
# 6    30  male     False         False     False     False      False
# 7    22  male      True          True      True     False      False
# 8    25  male     False          True     False     False      False
# 9    25  male     False          True     False     False      False
# 10   58  male      True         False      True     False      False
# 11   41  male      True          True      True      True       True
# 12   41  male      True          True      True      True       True
# ...

# %%
sorted_df = df.sort_values(by=['age', 'sgot', 'protime'])
sorted_df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 110    7  female    True       False   False   False    False      True
# 37    20    male   False       False    True    True     True     False
# 121   20  female   False       False    True    True     True      True
# 148   20  female   False       False   False   False    False      True
# 20    22    male    True        True    True   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 83    67    male   False       False    True    True    False      True
# 115   69    male    True       False    True   False    False      True
# 147   70  female   False       False    True    True     True       NaN
# 133   72  female    True        True    True   False    False      True
# 2     78  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
transposed_df = sorted_df.transpose()

# %%
melted_df = pd.melt(df, id_vars=['sex'], value_vars=['age', 'sgot', 'protime'])
melted_df
# Out:
#         sex variable  value
# 0      male      age   30.0
# 1    female      age   50.0
# 2    female      age   78.0
# 3    female      age   31.0
# 4    female      age   34.0
# ..      ...      ...    ...
# 460  female  protime   50.0
# 461  female  protime    NaN
# 462  female  protime    NaN
# 463    male  protime   48.0
# 464  female  protime   42.0
#
# [465 rows x 3 columns]

# %%
wide_df = melted_df.pivot_table(index='sex', columns='variable', values='value', aggfunc='mean')
wide_df
# Out:
# variable        age    protime       sgot
# sex
# female    41.165468  61.948052  86.437037
# male      41.500000  61.181818  81.312500
